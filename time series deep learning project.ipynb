# %% [markdown]
# # **Time Series Forecasting with LSTM-RNN: Code Explanation and Insights**
#
# ---
#
# ## **1. Purpose of Business Research**
#
# The purpose of this research is to **forecast future values** based on historical time series data. Using LSTM (Long Short-Term Memory) with RNN (Recurrent Neural Network), the solution is designed to model sequential patterns efficiently. Businesses use this approach to:
#
# - Optimize operational efficiency.
# - Improve decision-making with **data-driven forecasts**.
# - Reduce uncertainties in demand or trend predictions.
#
# The provided implementation predicts **sales trends** in a sample dataset but can be generalized to other domains.
#
# ---
#
# ## **2. Multi-Purpose Usage in Multiple Domain Business Scenarios**
#
# Time series forecasting with **LSTM-RNN** has broad applicability across multiple industries:
#
# 1. **Retail and E-commerce**:
#    - Predict **product sales** or seasonal demand to optimize inventory management.
#    - Forecast revenue trends for specific categories.
#
# 2. **Finance and Stock Markets**:
#    - Predict **stock prices**, interest rates, and financial indices.
#    - Analyze time series for risk management and investment decisions.
#
# 3. **Energy and Utilities**:
#    - Forecast **energy consumption** for grid management.
#    - Predict renewable energy generation for sustainability efforts.
#
# 4. **Healthcare**:
#    - Analyze patient admission rates over time.
#    - Forecast disease outbreaks or seasonal illness trends.
#
# 5. **Manufacturing and Supply Chain**:
#    - Optimize production schedules by predicting product demand.
#    - Analyze **delivery times** and inventory levels.
#
# 6. **Climate and Weather**:
#    - Predict weather conditions, rainfall, or temperature.
#    - Model climate change effects over time.
#
# This implementation is **domain-agnostic**, making it flexible for multiple business scenarios.
#
# ---
#
# ## **3. Research Work Related Insights**
#
# The solution involves:
#
# - **Time Series Data**: Analyzing sequential trends where current values depend on past events.
# - **Deep Learning Models**: Using **LSTM**, a specialized RNN capable of learning long-term dependencies in sequential data.
# - **Scalability**: Designed for real-world business scenarios where vast datasets are processed.
# - **Model Persistence**: Saving trained models and scalers for reuse to ensure deployment readiness.
# - **Evaluation Metrics**: Focus on model interpretability with metrics such as:
#    - MSE (Mean Squared Error)
#    - RMSE (Root Mean Squared Error)
#    - MAE (Mean Absolute Error)
#    - R² Score
#    - Explained Variance
#
# **Visualizations** like residual distributions, predictions vs actual values, and confusion matrices (for discretized values) enhance the understanding of model performance.
#
# ---
#
# ## **4. Technical Details on Coding Parts**
#
# #### **A. Dataset and Preprocessing**
#
# - **TimeSeriesDataset**:
#    - Custom PyTorch Dataset class to structure sequential data into `(input, target)` pairs.
# - **MinMaxScaler**:
#    - Scales the data between 0 and 1 for better LSTM performance.
#
# #### **B. LSTM-RNN Model**
#
# - **Model Architecture**:
#    - `nn.LSTM`: Processes sequential data with:
#      - `input_size`: Number of features per time step.
#      - `hidden_size`: Number of neurons in hidden layers.
#      - `num_layers`: Stack multiple LSTM layers.
#      - `dropout`: Regularization for overfitting prevention.
#    - `nn.Linear`: Maps the LSTM output to the final prediction.
#
# #### **C. Pipeline for Training and Prediction**
#
# - **Training**:
#    - Adam Optimizer with **MSE Loss**.
#    - DataLoader batches the data into input sequences.
# - **Prediction**:
#    - Inference is performed on new or unseen time series data.
#
# #### **D. Saving and Loading the Model**
#
# - **Persistence**:
#    - Model weights are saved using `torch.save()`.
#    - MinMaxScaler is saved with `joblib`.
#
# #### **E. Model Evaluation and Visualization**
#
# - **Metrics**:
#    - `mean_squared_error`
#    - `mean_absolute_error`
#    - `r2_score`
#    - `explained_variance_score`
#
# - **Visualizations**:
#    - Predictions vs Actual Sales
#    - Residual Distribution
#    - Confusion Matrix (Discretized Predictions)
#
# #### **F. File Storage**
#
# Predictions are stored in multiple formats:
# - **CSV**: Easy to view and share.
# - **Excel**: Supports tabular analysis.
# - **JSON**: Useful for APIs or web applications.
# - **Parquet**: Optimized for big data processing.
#
# ---
#
# ## **5. Future Advanced Options to Explore**
#
# #### **A. Next-Level Technologies**
# 1. **Attention Mechanism**:
#    - Enhance LSTM with attention layers to focus on important time steps.
# 2. **Transformer Models**:
#    - Use transformer-based models like **Informer** for faster, scalable time series forecasting.
# 3. **Hybrid Models**:
#    - Combine LSTM with ARIMA (Auto-Regressive Integrated Moving Average) or Prophet for mixed accuracy improvements.
#
# #### **B. Advanced Features**
# 1. **Multi-Feature Inputs**:
#    - Incorporate additional data (e.g., promotions, holidays) to enrich predictions.
# 2. **Anomaly Detection**:
#    - Use LSTM for detecting unexpected deviations in time series data.
# 3. **Real-Time Forecasting**:
#    - Deploy models for live prediction with streaming data inputs.
#
# #### **C. Business Research**
# - **Scenario Simulations**:
#    - Predict future outcomes under various simulated conditions (e.g., economic trends).
# - **Explainable AI (XAI)**:
#    - Apply SHAP or LIME to understand model decisions and enhance trust.
#
# ---
#
# ## **6. Summary and Conclusions**
#
# 1. **Purpose of Research**:
#    - Forecast future values using time series data with LSTM-RNN.
#    - Address uncertainties in business processes.
#
# 2. **Multi-Purpose Usage**:
#    - Applied across domains: retail, finance, energy, healthcare, and manufacturing.
#
# 3. **Research Insights**:
#    - Utilizes deep learning (LSTM) for long-term dependencies.
#    - Model evaluation ensures reliable predictions.
#
# 4. **Technical Details**:
#    - Data preprocessing: Scaling and cleaning.
#    - LSTM architecture for sequential modeling.
#    - Multiple metrics and visualizations for robust evaluation.
#    - Model persistence with file storage in diverse formats (CSV, Excel, JSON, Parquet).
#
# 5. **Future Directions**:
#    - Incorporate attention mechanisms and transformers for enhanced accuracy.
#    - Add real-time capabilities and anomaly detection.
#
# ---
#
# ## **Conclusion**
# The solution presented is a comprehensive **time series forecasting pipeline** that combines deep learning with robust evaluation and flexible deployment options. It provides actionable insights for businesses and lays a strong foundation for advanced AI/ML research and real-world applications.
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀uation and flexible deployment options. It provides actionable insights for businesses and lays a strong foundation for advanced AI/ML research and real-world applications. 🚀

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (c:\Users\vanimaha\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\vanimaha\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\vanimaha\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install fastparquet
# Out:
# ...
#    ---------------------------------------- 0.0/673.3 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/673.3 kB ? eta -:--:--
#    ---------------------------------------- 673.3/673.3 kB 1.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 2.8 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.9 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [fastparquet]
#    -------------------- ------------------- 1/2 [fastparquet]
#    -------------------- ------------------- 1/2 [fastparquet]
#    -------------------- ------------------- 1/2 [fastparquet]
#    ---------------------------------------- 2/2 [fastparquet]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score, explained_variance_score, 
    confusion_matrix, ConfusionMatrixDisplay
)
import joblib
import os

# 1. Seed Manager
class AndroSeedManager:
    @staticmethod
    def set_seed(seed=42):
        np.random.seed(seed)
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
AndroSeedManager.set_seed()

# 2. Custom Dataset Class for Time Series
class TimeSeriesDataset(Dataset):
    def __init__(self, data, seq_len):
        self.data = data
        self.seq_len = seq_len

    def __len__(self):
        return len(self.data) - self.seq_len

    def __getitem__(self, index):
        x = self.data[index:index + self.seq_len]
        y = self.data[index + self.seq_len]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

# 3. Custom LSTM RNN Time Series Model
class AndroLSTMRNNTimeSeries(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super(AndroLSTMRNNTimeSeries, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        return self.fc(lstm_out[:, -1, :])  # Take the output of the last time step

# 4. Custom Class for Training, Evaluation, and Inference
class AndroTimeSeriesPipeline:
    def __init__(self, model_params, seq_len=10):
        self.seq_len = seq_len
        self.model = AndroLSTMRNNTimeSeries(**model_params)
        self.scaler = MinMaxScaler()

    def preprocess_data(self, data):
        """Clean and scale data"""
        data = data.dropna()
        scaled_data = self.scaler.fit_transform(data.values.reshape(-1, 1))
        return scaled_data

    def train(self, train_data, epochs=50, batch_size=32, lr=0.001):
        """Train the LSTM-RNN model"""
        train_loader = DataLoader(TimeSeriesDataset(train_data, self.seq_len), batch_size=batch_size, shuffle=False)
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        criterion = nn.MSELoss()

        self.model.train()
        for epoch in range(epochs):
            epoch_loss = 0
            for x_batch, y_batch in train_loader:
                x_batch = x_batch.view(-1, self.seq_len, 1)
                optimizer.zero_grad()
                outputs = self.model(x_batch)
                loss = criterion(outputs.squeeze(), y_batch)
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()

            print(f"Epoch {epoch + 1}/{epochs}, Loss: {epoch_loss / len(train_loader):.4f}")

    def predict(self, data):
        """Make predictions using the trained model"""
        self.model.eval()
        test_loader = DataLoader(TimeSeriesDataset(data, self.seq_len), batch_size=1, shuffle=False)
        predictions = []
        with torch.no_grad():
            for x_batch, _ in test_loader:
                x_batch = x_batch.view(1, self.seq_len, 1)
                pred = self.model(x_batch).item()
                predictions.append(pred)
        return np.array(predictions)

    def save_model(self, model_path="andro_lstm_rnn_model_v2.pth", scaler_path="scaler_v2.pkl"):
        """Save the model and scaler"""
        torch.save(self.model.state_dict(), model_path)
        joblib.dump(self.scaler, scaler_path)
        print("Model and scaler saved successfully.")

    def load_model(self, model_path="andro_lstm_rnn_model_v2.pth", scaler_path="scaler_v2.pkl"):
        """Load the pretrained model and scaler"""
        self.model.load_state_dict(torch.load(model_path))
        self.scaler = joblib.load(scaler_path)
        print("Model and scaler loaded successfully.")

# 5. Usage Example with Extended Evaluation
if __name__ == "__main__":
    # Generate Sample Sales Data
    dates = pd.date_range(start="2023-01-01", periods=300)
    sales = np.sin(np.linspace(0, 50, 300)) * 50 + np.random.randn(300) * 5 + 100
    data = pd.DataFrame({"Date": dates, "Sales": sales})
    data.set_index("Date", inplace=True)

    # Hyperparameters
    model_params = {
        "input_size": 1,
        "hidden_size": 64,
        "num_layers": 2,
        "dropout": 0.2
    }

    # Initialize Pipeline
    pipeline = AndroTimeSeriesPipeline(model_params, seq_len=10)
    scaled_data = pipeline.preprocess_data(data)

    # Train Model
    pipeline.train(scaled_data, epochs=20, batch_size=16, lr=0.001)

    # Save Model and Scaler
    pipeline.save_model()

    # Reload Model
    pipeline.load_model()

    # Make Predictions
    predictions_loaded = pipeline.predict(scaled_data)
    actual = pipeline.scaler.inverse_transform(scaled_data[10:])
    predictions_rescaled = pipeline.scaler.inverse_transform(predictions_loaded.reshape(-1, 1))

    # Model Metrics
    mse = mean_squared_error(actual, predictions_rescaled)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(actual, predictions_rescaled)
    r2 = r2_score(actual, predictions_rescaled)
    evs = explained_variance_score(actual, predictions_rescaled)

    print("\nModel Metrics After Loading:")
    print(f"Mean Squared Error (MSE): {mse:.4f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Mean Absolute Error (MAE): {mae:.4f}")
    print(f"R² Score: {r2:.4f}")
    print(f"Explained Variance: {evs:.4f}")

    # Visualization
    plt.figure(figsize=(12, 6))
    plt.plot(data.index[10:], actual, label="Actual Sales", color="blue")
    plt.plot(data.index[10:], predictions_rescaled, label="Predicted Sales", color="orange", linestyle="--")
    plt.title("Predictions vs Actual Sales")
    plt.xlabel("Date")
    plt.ylabel("Sales")
    plt.legend()
    plt.show()

    # Save Predictions in Multiple Formats
    submission_df = pd.DataFrame({"Date": data.index[10:], "Predicted_Sales": predictions_rescaled.flatten()})

    submission_df.to_csv("sales_predictions.csv", index=False)
    submission_df.to_excel("sales_predictions.xlsx", index=False)
    submission_df.to_json("sales_predictions.json", orient="records")
    submission_df.to_parquet("sales_predictions.parquet", engine="fastparquet", index=False)

    print("Predictions saved in CSV, Excel, JSON, and Parquet formats.")
# Out:
# c:\Users\vanimaha\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\loss.py:634: UserWarning: Using a target size (torch.Size([16, 1])) that is different to the input size (torch.Size([16])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# c:\Users\vanimaha\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\loss.py:634: UserWarning: Using a target size (torch.Size([2, 1])) that is different to the input size (torch.Size([2])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1/20, Loss: 0.2174
# Epoch 2/20, Loss: 0.0861
# Epoch 3/20, Loss: 0.0806
# Epoch 4/20, Loss: 0.0773
# Epoch 5/20, Loss: 0.0747
# Epoch 6/20, Loss: 0.0727
# Epoch 7/20, Loss: 0.0721
# Epoch 8/20, Loss: 0.0712
# ...
